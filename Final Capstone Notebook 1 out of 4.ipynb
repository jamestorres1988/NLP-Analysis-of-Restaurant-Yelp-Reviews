# %% [markdown]
# # Final Capstone Notebook 1 out of 4
#
# Due to size constraints, we cannot load the original dataset into a google collab format notebook. As a result, we will need to load the dataset in a jupyter notebook, prep the data, and export it to a CSV. The original dataset can be found [here](https://www.kaggle.com/yelp-dataset/yelp-dataset/version/6?select=yelp_business.csv). Although there is a lot of information to work with, we will mostly be using the business table, the reviews table, and the tips table.

# %%
import pandas as pd
import spacy
import re
import warnings

warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# # Load Dataset
#
# Due to the size of the dataset, we would have to sample only one city for our analysis (Cleveland, Ohio). The business table will be used to filter the reviews and tips to a single city. Then, we will text clean the reviews and tips. Because the tips are unlabeled, we will have to create a sentiment classifier to give them labels. Only then can we combine the tips with the reviews for topic extraction. The classifier and topic extraction will be explored in the other two notebooks.

# %%
# Load the datset
path = "C:\\Users\\James\\Desktop\\Data_Folder\\yelp\\"

biz=pd.read_csv(path + "yelp_business.csv")
reviews=pd.read_csv(path + "yelp_review.csv")
tips=pd.read_csv(path + "yelp_tip.csv")

# %%
# Remove unnecessary columns; note that stars is total stars for biz
col = ['neighborhood', 'address', 'latitude', 'longitude', 'stars']
biz.drop(columns=col, inplace=True)       

# Update categories so that it's a list and not a string
biz.categories = biz.categories.apply(lambda x: x.split(";"))

# We will filter open restaurants in Cleveland, OH only
biz = biz[
    (biz.city == 'Cleveland') & 
    (biz.state == 'OH') & 
    (biz.is_open == 1) & 
    (biz.categories.apply(
        lambda x: True if 'Restaurants' in x else False
    ))]

# %%
df = pd.merge(reviews, biz, how='inner', on='business_id')

df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  OPZsR2jCG72uoDNjU71DQQ  qYbWTWH5leltA0bzWAOnmA  meXjqyhTNLFmknY39y2sMg
# 1  fxGwEiSYDtAen8BNuVGGxg  8Az_JgEpXqAii_5EDkw2tw  meXjqyhTNLFmknY39y2sMg
# 2  Gweb4pADeQ26WnaiKEZ7GQ  T9tEic49JZjN4nCUcDvrRQ  meXjqyhTNLFmknY39y2sMg
# 3  P1vhwPI56SeZEz10ywaS7w  W1p8_CFW5FISSihmQo5Qzw  meXjqyhTNLFmknY39y2sMg
# 4  1kQvQlBX0V5_rGddBh9-rQ  Y_PP05RRdzbKRYfDCCfh8w  meXjqyhTNLFmknY39y2sMg
#
#    stars        date                                               text  \
# 0      5  2014-09-11  Solid beers -- Christmas Ale defines my holida...
# 1      3  2013-10-13  Meh.  It was OK.  A bartender the night before...
# 2      4  2014-01-15  Oh Christmas Ale, oh Christmas Ale, how lovely...
# 3      3  2012-02-09  What is the big deal about this place? The foo...
# 4      5  2017-04-30  Great Lakes Brewing Company is one of my favor...
#
#    useful  funny  cool                           name       city state  \
# 0       1      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 1       0      1     0  "Great Lakes Brewing Company"  Cleveland    OH
# 2       1      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 3       2      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 4       0      0     0  "Great Lakes Brewing Company"  Cleveland    OH
#
#   postal_code  review_count  is_open  \
# 0       44113           751        1
# 1       44113           751        1
# 2       44113           751        1
# 3       44113           751        1
# 4       44113           751        1
#
#                                           categories
# 0  [Breweries, Restaurants, Event Planning & Serv...
# 1  [Breweries, Restaurants, Event Planning & Serv...
# 2  [Breweries, Restaurants, Event Planning & Serv...
# 3  [Breweries, Restaurants, Event Planning & Serv...
# 4  [Breweries, Restaurants, Event Planning & Serv...

# %%
# still have a lot of rows and no null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56910 entries, 0 to 56909
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     56910 non-null  object
#  1   user_id       56910 non-null  object
#  2   business_id   56910 non-null  object
#  3   stars         56910 non-null  int64
#  4   date          56910 non-null  object
#  5   text          56910 non-null  object
#  6   useful        56910 non-null  int64
#  7   funny         56910 non-null  int64
#  8   cool          56910 non-null  int64
#  9   name          56910 non-null  object
#  10  city          56910 non-null  object
#  11  state         56910 non-null  object
#  12  postal_code   56880 non-null  object
#  13  review_count  56910 non-null  int64
#  14  is_open       56910 non-null  int64
#  15  categories    56910 non-null  object
# dtypes: int64(6), object(10)
# memory usage: 7.4+ MB

# %% [markdown]
# # Text Cleaning
#
# If you look at the filtered dataframe below, you can see that some of the text has Chinese, Korean, & Japanese characters. We need to make a decision about how we will handle them. One option is to ignore them and allow them to stay in our data. The problem is that there is so few entries with CJK characters that our sentiment classifier and our topic extractor will only pick them up as noise.
#
# The second option is to remove the sentences completely that have these characters. However, some sentences have clear sentiments but only a word or two in CJK with the rest in English. We don't want to lose this info.
#
# The third option is to simply remove the characters from the sentences but keep the sentences intact. This method has some weaknesses since we have entire sentences in CJK characters. However, a majority of the sentences with CJK characters only have a few number of words per sentence. As a result, we will take this third option despite it's shortcomings.

# %%
# This function will be used to detect CJK characters
def cjk_detect(texts):
    # korean
    if re.search("[\uac00-\ud7a3]", texts):
        return True
    # japanese
    if re.search("[\u3040-\u30ff]", texts):
        return True
    # chinese
    if re.search("[\u4e00-\u9FFF]", texts):
        return True
    return False

# %%
# Let's filter the df
df[df.text.apply(cjk_detect)]
# Out:
#                     review_id                 user_id             business_id  \
# 1596   S2QzbvWSzg55eotbFUnWlg  ud2S2pG_8wtQiiZEonvYhw  WHlbUb5SNdXDKYfkNDo89A
# 9533   D7_28LOkVPoYE0d3xdpOMA  ww6SJqoqDDlJRj-f6B56Ew  1veVZUawy7IhIc5oDpRRQA
# 10270  HVyd1pdbzR9_Y3oWfyupgw  XhyK4GaKHh3dzSeHfsfsvQ  tulUhFYMvBkYHsjmn30A9w
# 12694  qFLoCT9-2d_MVJchyQZQcg  bLNS2BFfa9PTxCbT5jJztA  wftmt-n8OUA4Ng3bWWH5dw
# 16230  IRi2mraRE6le1ZRUwnWOMA  7Sq9MNNDseNy9AobzAms3A  ijY4C4ut4M9xg3QvK2R2pg
# 47607  OwD0tbtQ_IshoAP9_g5h4A  qJUg9tZHjaKZM9ap6I02XQ  97V91GSG-OQvrvOc9GXoGA
# 47608  ECStzVCNh__sejmXig1NOw  Hauunbq-IwLpF5v15Yomvg  97V91GSG-OQvrvOc9GXoGA
# 47609  _ASi-LfK1zNr_rJntAlcQA  xesTPySltXqeZytj1BtlAw  97V91GSG-OQvrvOc9GXoGA
# 47624  WoKqZMdHlHRfUyTMVnVEhQ  YaMwa5PgvH7jRjcVV1urtg  97V91GSG-OQvrvOc9GXoGA
# 47634  rOxjQr6u_UbgqkECdK2LUQ  54wFAWXdrJ8ppF8vDSQXAA  97V91GSG-OQvrvOc9GXoGA
# 47637  frlL3BTEVZ3rce_sidfhsg  4bsY6oCXNMo4MgUEcHeCIA  97V91GSG-OQvrvOc9GXoGA
# 47640  Qoprl27BEtyN8_xhfrz7WQ  e37pZZtvHDVAb_5KgfviIQ  97V91GSG-OQvrvOc9GXoGA
# 47664  6M1qafvF5WWOjUtu2hwGXg  w83G4nvDwxXiGQViAHemIQ  97V91GSG-OQvrvOc9GXoGA
# 47672  Lm-vIjSScjicHSpupQEXPA  3oou_lmA0zv5EenDkn5hqA  97V91GSG-OQvrvOc9GXoGA
# 47678  kCKNTK3oWehxs2CgvU9o8w  TwEQPdQybR50LdCxEcBpdA  97V91GSG-OQvrvOc9GXoGA
# 47690  q9me3WqaF4sXWo5Xm82OTQ  4QazAwPkW0LRVFEL7Uf1Fg  97V91GSG-OQvrvOc9GXoGA
# 47698  1LuwzAz7QZZM3zGw6zj5BQ  n8knso4sVoLixHyMYfX_eg  97V91GSG-OQvrvOc9GXoGA
# 52039  Qk06l2RSsT_u6MpFZ8y7sw  H409BZkbCg14CLw0658RcA  cRTkev8c66o6q6v7FstjLA
# 52054  I4G0JesShZ388B1a09c-fQ  acNDOIzwK48PU0MNPLQ48Q  cRTkev8c66o6q6v7FstjLA
# 53055  QK9MXC4N1lbV3zaqQZNuiw  ZxlQ7Lv2RzMm9sDfsRzyFQ  tZpxk604kWWHsJKyirraZg
# 54740  UyTnGYrfXjW-KQAnipoe_g  hy4uEHgITEfzxrXzyDhCRg  loXkZgAd70KMjP8ISCnZPQ
#
#        stars        date                                               text  \
# 1596       2  2017-02-26  店の雰囲気、立地は良いと思った。\nただし、とにかくオーダーしてから食事が来るのが遅い。飲み...
# 9533       5  2015-10-30  早餐只供應到11:00，可惜沒吃到，但他的sandwich 還是很精彩; Corned Be...
# 10270      2  2017-07-04  Finally decided to see what all the hype was a...
# 12694      5  2016-09-18  Wonton is a great place to go with a large gro...
# 16230      3  2015-10-29  To be fair.... It was decent. It's the only Di...
# 16381      3  2015-06-21  There's always a long line around lunch time, ...
# 17866      5  2016-01-01  Very good food. Waiter checked gluten for us. ...
# 17882      5  2015-08-05  I was ready for this seedy-looking restaurant ...
# 12694       8      6     6                    "Wonton Gourmet & BBQ"
# 16230       3      1     0                                  "Li Wah"
# 16381      14     10    12                                  "Li Wah"
# 17866       0      0     0                        "Szechuan Gourmet"
# 17882       9      5     7                        "Szechuan Gourmet"
# 17885       0      0     0                        "Szechuan Gourmet"
# 17969       2      0     0                        "Szechuan Gourmet"
# 17983       2      0     2                        "Szechuan Gourmet"
# 20349       0      0     0               "Han Chinese Kabob & Grill"
# 33889      15     10     9                       "Asia Food Company"
# 33897       2      1     1                             "Kung Fu Tea"
# 34017       2      0     2                        "Emperor's Palace"
# 34116       0      2     0                               "Siam Cafe"
# 34130       1      0     0                               "Siam Cafe"
# 34497       5      7     4                                 "Jukebox"
# 36108       0      0     0                             "La Pizzeria"
# 39028       2      0     0                            "Mama Santa's"
# 41916       0      0     0                      "Balaton Restaurant"
# 46254       0      0     0                              "Hunan East"
# 47575       4      1     3                            "Phusion Cafe"
# 47581       0      0     0                            "Phusion Cafe"
# 47601       0      0     0                            "Phusion Cafe"
# 47602       0      0     0                            "Phusion Cafe"
# 47607       0      0     0                            "Phusion Cafe"
# 47608       0      0     0                            "Phusion Cafe"
# 47609       0      0     0                            "Phusion Cafe"
# 47624       8      2     0                            "Phusion Cafe"
# 47634       3      0     1                            "Phusion Cafe"
# 47637       0      0     0                            "Phusion Cafe"
# 47640       0      0     0                            "Phusion Cafe"
# 47664       1      0     0                            "Phusion Cafe"
# 47672       1      0     1                            "Phusion Cafe"
# 47678       0      0     0                            "Phusion Cafe"
# 47690       7      4     4                            "Phusion Cafe"
# 47698       0      0     0                            "Phusion Cafe"
# 52039       0      1     0                           "Szechuan Cafe"
# 52054       6      0     0                           "Szechuan Cafe"
# 53055       4      1     4                             "LJ Shanghai"
# 54740       7      5     4                           "China Express"
#
#             city state postal_code  review_count  is_open  \
# 1596   Cleveland    OH       44115           128        1
# 9533   Cleveland    OH       44114           385        1
# 10270  Cleveland    OH       44103           162        1
# 12694  Cleveland    OH       44114           220        1
# 16230  Cleveland    OH       44114           246        1
# 16381  Cleveland    OH       44114           246        1
# 17866  Cleveland    OH       44114           165        1
# 17882  Cleveland    OH       44114           165        1
# 17885  Cleveland    OH       44114           165        1
# 17969  Cleveland    OH       44114           165        1
# 17983  Cleveland    OH       44114           165        1
# 20349  Cleveland    OH       44114            75        1
# 33889  Cleveland    OH       44114            27        1
# 33897  Cleveland    OH       44106            35        1
# 34017  Cleveland    OH       44114           100        1
# 34116  Cleveland    OH       44114           187        1
# 34130  Cleveland    OH       44114           187        1
# 34497  Cleveland    OH       44113            55        1
# 36108  Cleveland    OH       44106            39        1
# 39028  Cleveland    OH       44106           234        1
# 41916  Cleveland    OH       44120            95        1
# 46254  Cleveland    OH       44143            69        1
# 47575  Cleveland    OH       44114           128        1
# 47581  Cleveland    OH       44114           128        1
# 47601  Cleveland    OH       44114           128        1
# 47602  Cleveland    OH       44114           128        1
# 47607  Cleveland    OH       44114           128        1
# 47608  Cleveland    OH       44114           128        1
# 47609  Cleveland    OH       44114           128        1
# 47624  Cleveland    OH       44114           128        1
# 47634  Cleveland    OH       44114           128        1
# 47637  Cleveland    OH       44114           128        1
# 47640  Cleveland    OH       44114           128        1
# 47664  Cleveland    OH       44114           128        1
# 47672  Cleveland    OH       44114           128        1
# 47678  Cleveland    OH       44114           128        1
# 47690  Cleveland    OH       44114           128        1
# 47698  Cleveland    OH       44114           128        1
# 52039  Cleveland    OH       44114            33        1
# 52054  Cleveland    OH       44114            33        1
# 53055  Cleveland    OH       44114            25        1
# 54740  Cleveland    OH       44129            15        1
#
#                                               categories
# 1596   [Food, Lounges, Ice Cream & Frozen Yogurt, Ame...
# 9533   [Sandwiches, Restaurants, American (Traditional)]
# 10270                 [Soul Food, Restaurants, Barbeque]
# 12694        [Cantonese, Restaurants, Chinese, Barbeque]
# 16230         [Cantonese, Restaurants, Dim Sum, Chinese]
# 16381         [Cantonese, Restaurants, Dim Sum, Chinese]
# 17866                   [Restaurants, Chinese, Szechuan]
# 17882                   [Restaurants, Chinese, Szechuan]
# 17885                   [Restaurants, Chinese, Szechuan]
# 17969                   [Restaurants, Chinese, Szechuan]
# 17983                   [Restaurants, Chinese, Szechuan]
# 20349  [Kebab, Specialty Food, Chinese, Noodles, Soup...
# 33889  [Grocery, Restaurants, Japanese, Specialty Foo...
# 33897  [Restaurants, Juice Bars & Smoothies, Coffee &...
# 34017  [Chinese, Dim Sum, Vegetarian, Restaurants, Ca...
# 34116  [Chinese, Thai, Restaurants, Asian Fusion, Sea...
# 34130  [Chinese, Thai, Restaurants, Asian Fusion, Sea...
# 34497  [Bars, Arts & Entertainment, Cocktail Bars, Ni...
# 36108                 [Pizza, Restaurants, Gelato, Food]
# 39028   [Italian, Pizza, Sandwiches, Salad, Restaurants]
# 41916           [American (New), Hungarian, Restaurants]
# 46254                             [Restaurants, Chinese]
# 47575    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47581    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47601    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47602    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47607    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47608    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47609    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47624    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47634    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47637    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47640    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47664    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47672    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47678    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47690    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 47698    [Restaurants, Taiwanese, Chinese, Asian Fusion]
# 52039             [Szechuan, Soup, Chinese, Restaurants]
# 52054             [Szechuan, Soup, Chinese, Restaurants]
# 53055               [Shanghainese, Chinese, Restaurants]
# 54740                             [Restaurants, Chinese]

# %% [markdown]
# Because we are doing sentiment analysis, certain stopwords such as negatives (no, not, etc.) could completely reverse the sentiment if omitted. As a result, we should keep a few of them in. "Elsewhere" and "else" are popular words to use to express a negative review (i.e. "Go elsewhere for your food"). Also, the word "well" can be used to express positive sentiment (i.e. "Well done!" or "The food was prepared well.").

# %%
# Removes punctation, stops words, CJK, and lemmatizes
def lemma(text):
    lem_text = []
    
    for token in text:
        if (not token.is_punct and 
            not token.like_email and
            not token.like_url and
            not cjk_detect(token.text) and
            token not in all_stopwords and
            token.lemma_ not in all_stopwords): 
            lem_text.append(token.lemma_.lower())
    
    return " ".join(lem_text)

# %%
# create stopwords list
nlp = spacy.load("en_core_web_sm")
nlp.Defaults.stop_words.add("-PRON-")

exceptions = {'do', 'no', 'not', 'never', 
              'nothing', 'none', 'go', 
              'else', 'elsewhere', 'well', 
             }

all_stopwords = nlp.Defaults.stop_words
all_stopwords.difference_update(exceptions)
all_stopwords
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  '-PRON-',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'nevertheless',
#  'next',
#  'nine',
#  'nobody',
#  'noone',
#  'nor',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
# %%time
# let's create lemmatized sentences for the reviews
df['proc'] = list(nlp.pipe(iter(df.text), 
                           n_process=12, 
                           batch_size=1000))

df.loc[:,'lem_join'] = df.proc.apply(lambda x: lemma(x))

df.head()
# Out:
# Wall time: 4min 9s
#                 review_id                 user_id             business_id  \
# 0  OPZsR2jCG72uoDNjU71DQQ  qYbWTWH5leltA0bzWAOnmA  meXjqyhTNLFmknY39y2sMg
# 1  fxGwEiSYDtAen8BNuVGGxg  8Az_JgEpXqAii_5EDkw2tw  meXjqyhTNLFmknY39y2sMg
# 2  Gweb4pADeQ26WnaiKEZ7GQ  T9tEic49JZjN4nCUcDvrRQ  meXjqyhTNLFmknY39y2sMg
# 3  P1vhwPI56SeZEz10ywaS7w  W1p8_CFW5FISSihmQo5Qzw  meXjqyhTNLFmknY39y2sMg
# 4  1kQvQlBX0V5_rGddBh9-rQ  Y_PP05RRdzbKRYfDCCfh8w  meXjqyhTNLFmknY39y2sMg
#
#    stars        date                                               text  \
# 0      5  2014-09-11  Solid beers -- Christmas Ale defines my holida...
# 1      3  2013-10-13  Meh.  It was OK.  A bartender the night before...
# 2      4  2014-01-15  Oh Christmas Ale, oh Christmas Ale, how lovely...
# 3      3  2012-02-09  What is the big deal about this place? The foo...
# 4      5  2017-04-30  Great Lakes Brewing Company is one of my favor...
#
#    useful  funny  cool                           name       city state  \
# 0       1      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 1       0      1     0  "Great Lakes Brewing Company"  Cleveland    OH
# 2       1      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 3       2      1     1  "Great Lakes Brewing Company"  Cleveland    OH
# 4       0      0     0  "Great Lakes Brewing Company"  Cleveland    OH
#
#   postal_code  review_count  is_open  \
# 0       44113           751        1
# 1       44113           751        1
# 2       44113           751        1
# 3       44113           751        1
# 4       44113           751        1
#
#                                           categories  \
# 0  [Breweries, Restaurants, Event Planning & Serv...
# 1  [Breweries, Restaurants, Event Planning & Serv...
# 2  [Breweries, Restaurants, Event Planning & Serv...
# 3  [Breweries, Restaurants, Event Planning & Serv...
# 4  [Breweries, Restaurants, Event Planning & Serv...
#
#                                                 proc  \
# 0  (Solid, beers, --, Christmas, Ale, defines, my...
# 1  (Meh, .,  , It, was, OK, .,  , A, bartender, t...
# 2  (Oh, Christmas, Ale, ,, oh, Christmas, Ale, ,,...
# 3  (What, is, the, big, deal, about, this, place,...
# 4  (Great, Lakes, Brewing, Company, is, one, of, ...
#
#                                             lem_join
# 0  solid beer christmas ale define holiday season...
# 1  meh   ok   bartender night tell cleveland eat ...
# 2  oh christmas ale oh christmas ale lovely do ta...
# 3          big deal place food overprice beer do not
# 4  great lakes brewing company favorite place wor...

# %%
# %%time
# let's filter only tips for the businesses we want
tips = tips[tips['business_id'].isin(df.business_id.unique())]

# let's create lemmatized sentences for the tips
tips['proc'] = list(nlp.pipe(
    iter(tips.text), 
    n_process=12, 
    batch_size=1000
))

tips.loc[:,'lem_join'] = tips.proc.apply(lambda x: lemma(x))

# let's add names to tips
biz_dict = pd.Series(biz.name.values, 
                     index=biz.business_id).to_dict()

tips['name'] = tips.business_id.map(biz_dict)

tips.head()
# Out:
# Wall time: 34.6 s
#                                                    text        date  likes  \
# 124   The Cleveland Pickle is the best sandwich deli...  2012-10-20      0
# 382   A bit different. Out at a restaurant for Thank...  2010-11-25      0
# 596                                          Tab Benoit  2012-08-10      0
# 1140  One of the. Eat buffet I have been to in an ve...  2016-10-28      0
# 3557            Shipwreck! That's an awesome breakfast!  2010-09-11      0
#
#                  business_id                 user_id  \
# 124   MTsIckdo3_uKuqk3B4zuKA  MolXvMRbUNY6Yr_s0zEQ0A
# 382   0youcKV6-eE3F2MQj1l6Fw  blrWvPePSv87aU9hV1Zd8Q
# 596   CDqPVVvQtVncNQGydnZy7A  JE2qFjL4BaUbiI-cT5MSBw
# 1140  pGjtxXBq4tZcdKdgTU-Tww  a4pc6NRtbGkO7koP8qrVsg
# 3557  _5PJ4GHIXNdUdXtohylKGQ  ca___2Qaf5FFyPCf6T2eZA
#
#                                                    proc  \
# 124   (The, Cleveland, Pickle, is, the, best, sandwi...
# 382   (A, bit, different, ., Out, at, a, restaurant,...
# 596                                       (Tab, Benoit)
# 1140  (One, of, the, ., Eat, buffet, I, have, been, ...
# 3557  (Shipwreck, !, That, 's, an, awesome, breakfas...
#
#                                                lem_join  \
# 124   cleveland pickle good sandwich deli hand uniqu...
# 382   bit different restaurant thanksgiving buffet l...
# 596                                          tab benoit
# 1140                               eat buffet long time
# 3557                        shipwreck awesome breakfast
#
#                                  name
# 124                "Cleveland Pickle"
# 382                "100th Bomb Group"
# 596   "Beachland Ballroom and Tavern"
# 1140               "Little Hong Kong"
# 3557                   "Lucky's Café"

# %% [markdown]
# # Upload to CSV
#
# We will move these CSV files to a google drive to be uploaded to the google collab notebook. We will redundant columns before we do.

# %%
# let's remove unncecessary columns
col = ['city', 'state', 'postal_code', 
       'is_open', 'user_id', 'review_id', 
       'proc', 'categories']
df.drop(columns=col, inplace=True)  

# let's create a csv file
df.to_csv('yelp_reviews_lem.csv', index=False)

# %%
# let's remove unncecessary columns
col = ['user_id', 'proc']
tips.drop(columns=col, inplace=True)

# let's create a csv file
tips.to_csv('yelp_tips_lem.csv', index=False)
